# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # Dataset digits

# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
data_X = digits.data[:600]
y = digits.target[:600]

# %% [markdown]
# # Test PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_obj=pca.fit_transform(data_X)

# %%
pca_df = pd.DataFrame({'Xpca':pca_obj[:,0],
                        'Ypca':pca_obj[:,1],
                        'digit':y})
pca_df.head()
# Out:
#         Xpca       Ypca  digit
# 0 -18.883534   2.293896      0
# 1  21.814219   0.110379      1
# 2  12.952824   3.437552      2
# 3 -10.212207  -8.320957      3
# 4  15.606466  14.933918      4

# %%
sns.scatterplot(x="Xpca", y="Ypca",
              data=pca_df);

# %%
sns.scatterplot(x="Xpca", y="Ypca",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=pca_df);

# %% [markdown]
# # Test t-SNE

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)

# %%
tsne_obj= tsne.fit_transform(data_X)

# %%
tsne_df = pd.DataFrame({'Xtsne':tsne_obj[:,0],
                        'Ytsne':tsne_obj[:,1],
                        'digit':y})
tsne_df.head()
# Out:
#            X          Y  digit
# 0  32.482109 -25.342215      0
# 1 -19.354441  -4.162836      1
# 2 -14.874006   3.263016      2
# 3  23.132765   5.447344      3
# 4 -32.922100   0.126765      4

# %%
sns.scatterplot(x="Xtsne", y="Ytsne",
              data=tsne_df);

# %%
sns.scatterplot(x="Xtsne", y="Ytsne",
              hue="digit",
              palette=['purple','red','orange','brown','blue',
                       'dodgerblue','green','lightgreen','darkcyan', 'black'],
              legend='full',
              data=tsne_df);
